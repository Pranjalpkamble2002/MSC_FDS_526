# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjalpkamble2002/MSC_FDS_526/blob/main/FDS_PRACT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict={'Name':["a","b","c","d","d","e","f","g"],
         'age':[20,27,35,56,78,34,52,29],
         'designation':["vp","ceo","cfo","vp","ceo","vp","cfo","vp"]}

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(my_dict)
df
# Out:
#   Name  age designation
# 0    a   20          vp
# 1    b   27         ceo
# 2    c   35         cfo
# 3    d   56          vp
# 4    d   78         ceo
# 5    e   34          vp
# 6    f   52         cfo
# 7    g   29          vp

# %%
df.to_csv('csv example')
df
# Out:
#   Name  age designation
# 0    a   20          vp
# 1    b   27         ceo
# 2    c   35         cfo
# 3    d   56          vp
# 4    d   78         ceo
# 5    e   34          vp
# 6    f   52         cfo
# 7    g   29          vp

# %%
df_csv=pd.read_csv('Csv example')
df_csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-0aac41b765fa> in <module>
# ----> 1 df_csv=pd.read_csv('Csv example')
#       2 df_csv
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
